# %%
import pandas as pd
data=pd.read_csv("sales.csv")
data
# Out:
#     Transaction_ID        Date Customer_ID              Product  \
# 0             1001  2024-01-15     CUST001               Laptop
# 1             1002  2024-01-16     CUST002  Wireless Headphones
# 2             1003  2024-01-17     CUST003         Coffee Maker
# 3             1004  2024-01-18     CUST004           Desk Chair
# 4             1005  2024-01-19     CUST001          Office Desk
# 5             1006  2024-01-20     CUST005           Smartphone
# 6             1007  2024-01-21     CUST006              T-shirt
# 7             1008  2024-01-22     CUST007              Blender
# 8             1009  2024-01-23     CUST008        Running Shoes
# 9             1010  2024-01-24     CUST009              Monitor
# 10            1011  2024-01-25     CUST010         Notebook Set
# 11            1012  2024-01-26     CUST003            Microwave
# 12            1013  2024-01-27     CUST011               Tablet
# 13            1014  2024-01-28     CUST012               Jacket
# ...

# %%
# Total sales per row
data['Total'] = data['Quantity'] * data['Unit_Price']
data
# Out:
#     Transaction_ID        Date Customer_ID              Product  \
# 0             1001  2024-01-15     CUST001               Laptop
# 1             1002  2024-01-16     CUST002  Wireless Headphones
# 2             1003  2024-01-17     CUST003         Coffee Maker
# 3             1004  2024-01-18     CUST004           Desk Chair
# 4             1005  2024-01-19     CUST001          Office Desk
# 5             1006  2024-01-20     CUST005           Smartphone
# 6             1007  2024-01-21     CUST006              T-shirt
# 7             1008  2024-01-22     CUST007              Blender
# 8             1009  2024-01-23     CUST008        Running Shoes
# 9             1010  2024-01-24     CUST009              Monitor
# 10            1011  2024-01-25     CUST010         Notebook Set
# 11            1012  2024-01-26     CUST003            Microwave
# 12            1013  2024-01-27     CUST011               Tablet
# 13            1014  2024-01-28     CUST012               Jacket
# ...
